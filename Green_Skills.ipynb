# %%
#Celcius to Farenheit
celcius = 100
farenheit = (celcius*9/5 + 32)
print(f"Temp is {farenheit}")
# Out:
# Temp is 212.0

# %%
carbon_footprint = 7.00001
is_good = carbon_footprint < 7
print(f"Is the city sustainable? {is_good}")
# Out:
# Is the city sustainable? False

# %%
list1 = [1,2,3,4,5]
if( 1 in list1 )
print("Ruggu")
# Out:
#   Cell In[26], line 2
#     if( 1 in list1 )
#                     ^
# SyntaxError: expected ':'

# %%
#Write a for loop to filter the ratio of the cities with the high temperature
high_temp_threshold = 34

#Use a list comprehension to filter cities with temmperature higher  than the threshold
high_temp_cities = [city for city in climate_data if city["temperature"]]

#Print the result
print("Cities with  high temperature (> 26'C):")
for city in high_temp_cities:
    print(f"{city['city']}- {city['temperature']}C")

# %%
#write the  code to find the  city with the highest carbon footprint (you can use lambda function
energy_consumption = 1000 #in kwh
emmission_factorr = 0.475 # kg Co2 per kwh
Carbon_footprint = calculate_carbon_footprint(energy_consumption, emission_factor)
print

# %%
# Lambda function to check leap year
is_leap_year = lambda year: (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

# Input from user
year = int(input("Enter a year: "))

# Check if the year is a leap year
if is_leap_year(year):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2024 is a leap year.

# %%
import pandas as pd

renewable_sources = {"Wind","Solar","Geothermal","Hydropower"}

data = {
    "Project": ["Solar Farm A", "Wind Turbine X", "Hydropower Y", "Solar Roof Z", "Geothermal Plant P"],
    "Technology": ["Solar", "Wind", "Hydropower", "Solar", "Geothermal"],
    "Capacity (MW)": [150, 300, 200, 50, 100],  # Megawatts
    "Cost (Million $)": [200, 400, 350, 100, 250],  # Project cost
    "Location": ["California", "Texas", "Washington", "Nevada", "Idaho"],
    "Completion Year": [2023, 2024, 2022, 2025, 2023]
}

# %%
projects_df = pd.DataFrame(data)
projects_df.head()
# Out:
#               Project  Technology  Capacity (MW)  Cost (Million $)  \
# 0        Solar Farm A       Solar            150               200
# 1      Wind Turbine X        Wind            300               400
# 2        Hydropower Y  Hydropower            200               350
# 3        Solar Roof Z       Solar             50               100
# 4  Geothermal Plant P  Geothermal            100               250
#
#      Location  Completion Year
# 0  California             2023
# 1       Texas             2024
# 2  Washington             2022
# 3      Nevada             2025
# 4       Idaho             2023

# %%
selected_rows = projects_df.iloc[[1, 2]]
print(selected_rows)
# Out:
#           Project  Technology  Capacity (MW)  Cost (Million $)    Location  \
# 1  Wind Turbine X        Wind            300               400       Texas
# 2    Hydropower Y  Hydropower            200               350  Washington
#
#    Completion Year
# 1             2024
# 2             2022

# %%
projects_df.count()
# Out:
# Project             5
# Technology          5
# Capacity (MW)       5
# Cost (Million $)    5
# Location            5
# Completion Year     5
# dtype: int64

# %%
# Filter 
high_capacity_projects=projects_df[projects_df["Capacity (MW)"]>100]
# print(high_capacity_projects)
high_capacity_projects.head()
# print(type(high_capacity_projects))

# Cost per MW 
projects_df["Cost_per_MW"]=projects_df["Cost (Million $)"]/projects_df["Capacity (MW)"]

# %%
grouped_data = projects_df.groupby("Technology")["Capacity"].sum()
print("Total Capacity by technology\n")
print(grouped_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 grouped_data = projects_df.groupby("Technology")["Capacity"].sum()
#       2 print("Total Capacity by technology\n")
#       3 print(grouped_data)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
# ...

# %%
import numpy as np
twodarray = np.array([[1,2],[3,4]])
print(twodarray)
# Out:
# [[1 2]
#  [3 4]]

# %%
two_D = np.array([[1,2],[3,4]])
print(two_D.shape)
print(two_D.size)
print(two_D.ndim)
print(two_D.dtype)
print(two_D.itemsize)
# Out:
# (2, 2)
# 4
# 2
# int64
# 8

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
array1=np.arange(0,10,2)
print(array1)

array2 = np.arange(5,15,2)
print(array2)
# Out:
# [0 2 4 6 8]
# [ 5  7  9 11 13]

# %%
linspace_array1 = np.linspace(5,10,3)
print(linspace_array1)
# Out:
# [ 5.   7.5 10. ]

# %%
import numpy as np

num_data = np.array([[1, 2, 3], [4, 5, 6]])
reshaped_data = num_data.reshape(2, 3)
print(reshaped_data)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(num_data.flatten('F'))
# Out:
# [1 4 2 5 3 6]

# %%
# Create an array for energy consumption (in kWh)
energy_consumption = np.array([1200, 3400, 2900, 1800, 2500])

# Calculate the mean
mean_consumption = np.mean(energy_consumption)
print("Mean energy consumption (kWh):", mean_consumption)

# Calculate the median
median_consumption = np.median(energy_consumption)
print("Median energy consumption (kWh):", median_consumption)

# Calculate the standard deviation
std_dev_consumption = np.std(energy_consumption)
print("Standard deviation of energy consumption (kWh):", std_dev_consumption)

# Calculate the variance
variance_consumption = np.var(energy_consumption)
print("Variance of energy consumption (kWh):", variance_consumption)
# Out:
# Mean energy consumption (kWh): 2360.0
# Median energy consumption (kWh): 2500.0
# Standard deviation of energy consumption (kWh): 781.2809993849844
# Variance of energy consumption (kWh): 610400.0

# %%
data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150, 250, np.nan]
}

energy_df = pd.DataFrame(data)
print(energy_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
cleaned_df = energy_df.dropna()
cleaned_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0

# %%
ec_mean = energy_df["Energy Consumption (MWh)"].mean()
print("Mean of Energy Consumption",ec_mean)
# Out:
# Mean of Energy Consumption 2450.0

# %%
forwarded_filled_df = energy_df.fillna(method="ffill")
print("Data before Forward Filling\n")
print(energy_df)
# Out:
# Data before Forward Filling
#
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15160\2261055012.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   forwarded_filled_df = energy_df.fillna(method="ffill")

# %%
print("Data after Forward Filling\n")
forwarded_filled_df.head()
# Out:
# Data after Forward Filling
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                    1200.0             400.0
# 2    Hydropower                    2900.0             400.0
# 3    Geothermal                    2900.0             150.0
# 4       Biomass                    2500.0             250.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]]= scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])
print("Data after normalozation\n")
print(energy_df)
# Out:
# Data after normalozation
#
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                      0.00               0.2
# 1          Wind                       NaN               1.0
# 2    Hydropower                      0.85               NaN
# 3    Geothermal                       NaN               0.0
# 4       Biomass                      0.65               0.4
# 5       Nuclear                      1.00               NaN

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]]= scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])
print("Data after normalozation\n")
print(energy_df)
# Out:
# Data after normalozation
#
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                 -1.637804         -0.534522
# 1          Wind                       NaN          1.603567
# 2    Hydropower                  0.589610               NaN
# 3    Geothermal                       NaN         -1.069045
# 4       Biomass                  0.065512          0.000000
# 5       Nuclear                  0.982683               NaN

# %%
energy_encoded_df = pd.get_dummies(energy_df,columns=["Energy Source"])
print("Data after one-hot encoding")
energy_encoded_df.head()
# Out:
# Data after one-hot encoding
#    Energy Consumption (MWh)  Cost (Million $)  Energy Source_Biomass  \
# 0                 -1.637804         -0.534522                  False
# 1                       NaN          1.603567                  False
# 2                  0.589610               NaN                  False
# 3                       NaN         -1.069045                  False
# 4                  0.065512          0.000000                   True
#
#    Energy Source_Geothermal  Energy Source_Hydropower  Energy Source_Nuclear  \
# 0                     False                     False                  False
# 1                     False                     False                  False
# 2                     False                      True                  False
# 3                      True                     False                  False
# 4                     False                     False                  False
#
#    Energy Source_Solar  Energy Source_Wind
# ...

# %%
import matplotlib.pyplot as plt

#Sample data for energy consumption over 6 months (in Mich)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
energy_consumption= [1200, 1300, 1100, 1500, 1400, 1600]


#Create a Line plot
plt.plot(months, energy_consumption, marker='o', color='b', linestyle='--')

#Add titles and Labels
plt.title('Energy Consumption Over 6 Months')
plt.xlabel('Month')
plt.ylabel('Energy Consumption (MWh)')
plt.show()

# %%
import matplotlib.pyplot as plt

#Sample data for energy consumption over 6 months (in Mich)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
energy_consumption= [1200, 1300, 1100, 1500, 1400, 1600]


#Create a Line plot
plt.bar(months, energy_consumption, color = "green") 

#Add titles and Labels
plt.title('Energy Consumption Over 6 Months')
plt.xlabel('Month')
plt.ylabel('Energy Consumption (MWh)')
plt.show()

# %%
plt.pie(energy_consumption, labels=energy_consumption, autopct='%1.1f%%', startangle=90)

plt.title('Energy Consumption by Source')

plt.show()

# %%
# Sample data for energy consumption and carbon emissions

carbon_emissions = [200, 500, 450, 300,500,600] # in kg CO2

#Create a scatter plot

plt.scatter(energy_consumption, carbon_emissions, color='red')

#Add titles and Labels

plt.title('Energy Consumption vs Carbon Emissions')

plt.xlabel('Energy Consumption (MWh)')

plt.ylabel('Carbon Emissions (kg CO2)')

plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt

#Y-axis values

y1= [2, 3, 4.5]

#Y-axis values

y2= [1, 1.5, 5]

#Function to plot

plt.plot(y1)

plt.plot(y2)

#Function add a Legend

plt.legend(["blue", "green"], loc ="lower right")

#function to show the plot

plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#Creating a DataFrame for pair plot
data = {
"Solar": [1200, 1500, 1300],
"Wind": [3400, 3600, 3200],
"Hydropower": [2900, 3100, 2800],
"Blomass": [2500, 2700, 2400]
}

df =pd.DataFrame(data)
#a Ceate a pair plot 
sns.pairplot(df)
plt.show()

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
plt.title("Correlation between energy sources")
plt.show()

# %%
sns.boxplot(data=df)
plt.title("Distribution of Energy Consumption by Source")
plt.show()

# %%
sns.violinplot(data = df)
plt.title("Violin Plot of Energy Consumption Distributions")
plt.show()

# %%
energy_values = [100,200,300,400,500]
carbon_emissions = [10,20,25,40,50]

df_reg = pd.DataFrame({
    "Energy Consumption" : energy_values,
    "Carbon Emmisions" : carbon_emissions
})
sns.regplot(x="Energy Consumption", y= "Carbon Emmisions",data=df_reg)

plt.title("")
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
fig=plt.figure()
ax=plt.axes(projection='3d')
z = np.linspace(0,1,1000)
x=z*np.sin(25*z)
y=z*np.cos(25*z)
ax.plot3D(x,y,z,'green')
ax.set_title('3D line plot')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/ASUS/Downloads/IRIS.csv") 

# 1. Pair Plot
sns.pairplot(df)
plt.title('Pair Plot')
plt.show()

# %%
sns.pairplot(df,hue = 'species', palette="husl", size=2)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
df['species'] = df['species'].astype('category').cat.codes

corr = df.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlations')
# Show the plot
plt.show()

# %%
sns.boxplot(data=df)
plt.title('Box Plot')
plt.show()

# %%
sns.violinplot(data=df)
plt.title('Violin Plot')
plt.show()
